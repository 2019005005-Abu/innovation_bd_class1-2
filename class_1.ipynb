# %%
##class_1
import  matplotlib.pyplot as plt;
import numpy as np;
import pandas as pd;
import seaborn as sns;


image_path='../dataset/flower-image-dataset/bougainvillea/bougainvillea_00002.jpg';
image=plt.imread(image_path);
# img_height=1000;
# img_width=1000;
# img_resize=(img_height,img_width)
# resize=np.resize(image,img_resize);
plt.imshow(image);
plt.axis('off');
plt.title('Bougainvillea');
plt.show()
plt.imsave('bougainvillea.jpg',image);

# %%
##Using open cv to read image
import cv2;
import matplotlib.pyplot as plt;
import numpy as np;
image_path='../dataset/flower-image-dataset/daisies/daisies_00002.jpg';
image=cv2.imread(image_path);
plt.imshow(image)
plt.title('Daisies')
print(image.shape)
# Out:
# (1169, 1200, 3)

# %%
'''
Open cv uses BGR format to read image, so we need to convert it to RGB format by default.
'''
import cv2;
import matplotlib.pyplot as plt;
image_path='../dataset/flower-image-dataset/garden_roses/garden_roses_00003.jpg';
image=cv2.imread(image_path);
image_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
imgae_b=cv2.cvtColor(image,cv2.COLOR_RGB2BGR);
plt.imshow(image_rgb);

# %%
import cv2;
import matplotlib.pyplot as plt;
img_path='../dataset/flower-image-dataset/lilies/lilies_00002.jpg'
image=cv2.imread(image_path);
rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB);
bgr=cv2.cvtColor(image,cv2.COLOR_RGB2BGR);
hsv=cv2.cvtColor(image,cv2.COLOR_BGR2HSV);
blue,green,red=cv2.split(hsv);
plt.imshow(bgr);
plt.title('original image')
##Blue
plt.figure(figsize=(6,10));
plt.imshow(blue,cmap='gray')
plt.title('Blue channel')

##Green
plt.figure(figsize=(6,10));
plt.subplot(2,2,1)
plt.imshow(green,cmap='gray');
plt.title('Green channel')


plt.figure(figsize=(6,10));
plt.subplot(2,2,1);
plt.imshow(red,cmap='gray');
plt.title('Red channel')
# Out:
# Text(0.5, 1.0, 'Red channel')

# %%
import pillow as Image;
print(Image.__version__);
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 import pillow as Image;
#       2 print(Image.__version__);
#
# ModuleNotFoundError: No module named 'pillow'
